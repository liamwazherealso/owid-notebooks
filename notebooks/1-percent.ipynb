# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !cd ../; make owid_data_hash
# Out:
# { \
# 	cd owid-datasets/ ;\
# 	git rev-parse HEAD ;\
# }
# 6ffb8900332bb0d75ceb8da6cd37c4f313efaa63

# %%
DATA_PATH="../owid-datasets/datasets/Top 1% wealth shares - Chartbook of Economic Inequality (2017)/Top 1% wealth shares - Chartbook of Economic Inequality (2017).csv"

# %%
df = pd.read_csv(DATA_PATH)

# %%
df.head()
# Out:
#       Entity  Year  \
# 0  Australia  1915
# 1  Australia  1953
# 2  Australia  1954
# 3  Australia  1955
# 4  Australia  1956
#
#    Share of wealth held by top 1% (Chartbook of Economic Inequality 2017)
# 0                                              33.98
# 1                                              14.58
# 2                                              10.71
# 3                                               9.92
# 4                                              12.44

# %%
x_min, x_max = df["Year"].min(), df["Year"].max()

# %%
wealth = "Share of wealth held by top 1% (Chartbook of Economic Inequality 2017)"

y_min, y_max = df[wealth].min(), df[wealth].max()

# %%
df["Entity"].unique()
# Out:
# array(['Australia', 'Finland', 'France', 'Italy', 'Netherlands',
#        'New Zealand', 'Norway', 'Spain', 'Sweden', 'Switzerland',
#        'United Kingdom', 'United States'], dtype=object)

# %%
fig = plt.figure(figsize=(20,10))
for e in df["Entity"].unique(): 
    plt.plot(df[df["Entity"] == e]["Year"], df[df["Entity"] == e][wealth], label=e)
plt.axis([x_min, x_max, y_min, y_max ])
plt.legend(loc="upper left")
fig.suptitle('Share of wealth held by top 1% (Chartbook of Economic Inequality 2017)', fontsize=20)
plt.xlabel('year (Y)', fontsize=18)
plt.ylabel('percentage of wealth heald by top 1%', fontsize=16)
plt.show()
